# %%
import pandas as pd

# %%
test = pd.read_csv("us-county-boundaries.csv", engine="pyarrow", sep=";")

# %%
illinois = test[test["STATEFP"]==17]
illinois.index = pd.Index(range(0, len(illinois)))

# %%
illinois['FIPS'] = [(str(int(illinois["STATEFP"][i])//10)+str(int(illinois["STATEFP"][i])%10)+str(int(illinois["COUNTYFP"][i])//100)+str(int(illinois["COUNTYFP"][i])//10%10)+str(int(illinois["COUNTYFP"][i])%10)) for i in range(0, len(illinois))]
illinois
# Out:
# /tmp/ipykernel_59372/3347915558.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois['FIPS'] = [(str(int(illinois["STATEFP"][i])//10)+str(int(illinois["STATEFP"][i])%10)+str(int(illinois["COUNTYFP"][i])//100)+str(int(illinois["COUNTYFP"][i])//10%10)+str(int(illinois["COUNTYFP"][i])%10)) for i in range(0, len(illinois))]
#                          Geo Point  \
# 0    39.0855054887, -90.3565282985
# 1    41.4041459264, -89.5286557577
# 2    41.2044899818, -89.2857803179
# 3    40.2396222297, -89.9168137955
# 4    42.0425663561, -89.3207266558
# ..                             ...
# 97   39.0001785652, -89.0241202321
# 98   41.3440027805, -88.8859379256
# 99   40.7880635936, -89.7599800409
# 100  40.4037747348, -91.1646955496
# 101   40.4908916187, -88.847324278
#
#                                              Geo Shape  STATEFP  COUNTYFP  \
# 0    {"coordinates": [[[-90.592165, 39.086765], [-9...       17        83
# 1    {"coordinates": [[[-89.856913, 41.408836], [-8...       17        11
# 2    {"coordinates": [[[-89.333027, 41.132961], [-8...       17       155
# 3    {"coordinates": [[[-90.114921, 40.245482], [-9...       17       125
# 4    {"coordinates": [[[-89.685984, 42.112009], [-8...       17       141
# ..                                                 ...      ...       ...
# 97   {"coordinates": [[[-89.250603, 39.152012], [-8...       17        51
# 98   {"coordinates": [[[-89.166473, 41.541697], [-8...       17        99
# 99   {"coordinates": [[[-89.985333, 40.800074], [-8...       17       143
# 100  {"coordinates": [[[-91.374208, 40.463993], [-9...       17        67
# 101  {"coordinates": [[[-89.266499, 40.485552], [-8...       17       113
#
#      COUNTYNS  GEOID     NAME        NAMELSAD STUSAB  LSAD  ...   CBSAFP  \
# 0      424243  17083   Jersey   Jersey County     IL     6  ...  41180.0
# 1      424207  17011   Bureau   Bureau County     IL     6  ...  36837.0
# 2      424279  17155   Putnam   Putnam County     IL     6  ...  36837.0
# 3      424261  17125    Mason    Mason County     IL     6  ...      NaN
# 4     1784894  17141     Ogle     Ogle County     IL     6  ...  40300.0
# ..        ...    ...      ...             ...    ...   ...  ...      ...
# 97     424227  17051  Fayette  Fayette County     IL     6  ...      NaN
# 98     422247  17099  LaSalle  LaSalle County     IL     6  ...  36837.0
# 99    1784920  17143   Peoria   Peoria County     IL     6  ...  37900.0
# 100    424235  17067  Hancock  Hancock County     IL     6  ...  22800.0
# 101   1784833  17113   McLean   McLean County     IL     6  ...  14010.0
#
#     METDIVFP  FUNCSTAT       ALAND    AWATER     INTPTLAT      INTPTLON  \
# 0        NaN         A   957415147  20333975  +39.0801945  -090.3613850
# 1        NaN         A  2250935503  11472955  +41.4013043  -089.5283772
# 2        NaN         A   414649309  31195045  +41.1989613  -089.2983474
# 3        NaN         A  1396914851  62748513  +40.2369926  -089.9135746
# 4        NaN         A  1964903717  12378959  +42.0418840  -089.3201764
# ..       ...       ...         ...       ...          ...           ...
# 97       NaN         A  1855567160  22931323  +39.0011246  -089.0179232
# 98       NaN         A  2940070811  33698037  +41.3433407  -088.8859312
# 99       NaN         A  1602464183  30659935  +40.7859722  -089.7669933
# 100      NaN         A  2055798692  53563370  +40.4013180  -091.1688008
# 101      NaN         A  3064600918   7801224  +40.4945594  -088.8445391
#
#      STATE_NAME COUNTYFP NOZERO   FIPS
# 0      Illinois              83  17083
# 1      Illinois              11  17011
# 2      Illinois             155  17155
# 3      Illinois             125  17125
# 4      Illinois             141  17141
# ..          ...             ...    ...
# 97     Illinois              51  17051
# 98     Illinois              99  17099
# 99     Illinois             143  17143
# 100    Illinois              67  17067
# 101    Illinois             113  17113
#
# [102 rows x 23 columns]

# %%
test2 = pd.read_csv("racial.csv")
test2
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3189      50       4         8     56      37  Wyoming  Sweetwater County
# 3190      50       4         8     56      39  Wyoming       Teton County
# 3191      50       4         8     56      41  Wyoming       Uinta County
# 3192      50       4         8     56      43  Wyoming    Washakie County
# 3193      50       4         8     56      45  Wyoming      Weston County
#
#       ESTIMATESBASE2020  POPESTIMATE2020  POPESTIMATE2021  ...  RESIDUAL2021  \
# 0               5024279          5024803          5039877  ...           242
# 1                 58805            58877            59095  ...             8
# 2                231767           233140           239294  ...           -82
# 3                 25223            25180            24964  ...             1
# 4                 22293            22223            22477  ...            -1
# ...                 ...              ...              ...  ...           ...
# 3189              42272            42158            41614  ...            -4
# 3190              23331            23347            23575  ...             1
# 3191              20450            20441            20635  ...             0
# 3192               7685             7658             7705  ...            -1
# 3193               6838             6809             6745  ...             1
#
#       GQESTIMATESBASE2020  GQESTIMATES2020  GQESTIMATES2021  RBIRTH2021  \
# 0                  114572           114572           114572   11.191613
# 1                     442              442              442   11.002611
# 2                    2177             2177             2177    9.567474
# 3                    2789             2789             2789   10.928526
# 4                    2062             2062             2062   10.111857
# ...                   ...              ...              ...         ...
# 3189                  720              720              720   11.483551
# 3190                  215              215              215    9.377264
# 3191                  187              187              187   11.003993
# 3192                  119              119              119    9.893901
# 3193                  300              300              300    7.673012
#
#       RDEATH2021  RNATURALCHG2021  RINTERNATIONALMIG2021  RDOMESTICMIG2021  \
# 0      12.890226        -1.698613               0.247201          4.398749
# 1      11.545112        -0.542502               0.084766          4.017903
# 2      12.137145        -2.569671               0.266704         28.702422
# 3      15.714742        -4.786216               0.039885         -3.908743
# 4      12.617450        -2.505593               0.089485         13.825503
# ...          ...              ...                    ...               ...
# 3189    9.549730         1.933820               0.429738        -15.255694
# 3190    4.091897         5.285367               0.340991          4.049273
# 3191    8.082579         2.921414               0.146071          6.378420
# 3192   14.971034        -5.077133               0.000000         11.325913
# 3193   13.280212        -5.607201               0.000000         -3.984064
#
#       RNETMIG2021
# 0        4.645950
# 1        4.102668
# 2       28.969126
# 3       -3.868858
# 4       13.914989
# ...           ...
# 3189   -14.825956
# 3190     4.390265
# 3191     6.524491
# 3192    11.325913
# 3193    -3.984064
#
# [3194 rows x 35 columns]

# %%
illinois_data = test2[test2["STNAME"]=="Illinois"]
illinois_data.index = pd.Index(range(0,len(illinois_data)))

# %%
illinois["NAME"]
# Out:
# 0       Jersey
# 1       Bureau
# 2       Putnam
# 3        Mason
# 4         Ogle
#         ...
# 97     Fayette
# 98     LaSalle
# 99      Peoria
# 100    Hancock
# 101     McLean
# Name: NAME, Length: 102, dtype: object

# %%
superfund = pd.read_excel("superfund_sites.xlsx")
superfund
# Out:
#             EPA ID                                Site Name             City  \
# 0     NED981713837                         10TH STREET SITE         COLUMBUS
# 1     KSD007241656   29TH & MEAD GROUND WATER CONTAMINATION          WICHITA
# 2     ALN000410750                              35TH AVENUE       BIRMINGHAM
# 3     KSD981710247     57TH AND NORTH BROADWAY STREETS SITE          WICHITA
# 4     MDD980918387  68TH STREET DUMP/INDUSTRIAL ENTERPRISES         ROSEDALE
# ...            ...                                      ...              ...
# 1892  NYD000511733                             YORK OIL CO.            MOIRA
# 1893  AZ0971590062            YUMA MARINE CORPS AIR STATION             YUMA
# 1894  OHD980794598                    ZANESVILLE WELL FIELD       ZANESVILLE
# 1895  FLD049985302      ZELLWOOD GROUND WATER CONTAMINATION         ZELLWOOD
# 1896  NJD986643153                      ZSCHIEGNER REFINING  HOWELL TOWNSHIP
#
#          County State                   Street Address Zip Code Region  \
# 0        PLATTE    NE               28TH AVE & 10TH ST    68601    R07
# 1      SEDGWICK    KS  412 E 29TH N 26S 1E SW 1/4 S 33    67219    R07
# 2     JEFFERSON    AL                     3500 35TH N.    35207    R04
# 3      SEDGWICK    KS        57TH & N BROADWAY STREETS    67219    R07
# 4     BALTIMORE    MD                      68TH STREET    21237    R03
# ...         ...   ...                              ...      ...    ...
# 1892   FRANKLIN    NY                    N LAWRENCE RD    12957    R02
# 1893       YUMA    AZ                        AVENUE 3E    85369    R09
# 1894  MUSKINGUM    OH                      2200 LINDEN    43701    R05
# 1895     ORANGE    FL                    803 JONES AVE    32757    R04
# 1896   MONMOUTH    NJ         1442 MAXIM-SOUTHARD ROAD     7731    R02
#
#         NPL Status Partial NPL Deletion  ...  \
# 0        Final NPL                   No  ...
# 1      Deleted NPL                  Yes  ...
# 2     Proposed NPL                   No  ...
# 3        Final NPL                   No  ...
# 4     Proposed NPL                   No  ...
# ...            ...                  ...  ...
# 1892     Final NPL                   No  ...
# 1893     Final NPL                   No  ...
# 1894     Final NPL                   No  ...
# 1895     Final NPL                   No  ...
# 1896     Final NPL                   No  ...
#
#                                   Site Type Subcategory  \
# 0     Ground water plume site with no identifiable s...
# 1     Ground water plume site with no identifiable s...
# 2     Coal gasification, Residential, Spill or other...
# 3     Ground water plume site with no identifiable s...
# 4     Co-disposal landfill (municipal and industrial...
# ...                                                 ...
# 1892                                     Waste/used oil
# 1893  Trucks/ships/trains/aircraft and related compo...
# 1894  Ground water plume site with no identifiable s...
# 1895                                        Drums/tanks
# 1896  Batteries/scrap metals/secondary smelting/prec...
#
#              Federal Agency Native American Interest (NAI)  \
# 0                       NaN                             No
# 1                       NaN                             No
# 2                       NaN                             No
# 3                       NaN                             No
# 4                       NaN                             No
# ...                     ...                            ...
# 1892                    NaN                             No
# 1893  Department of Defense                             No
# 1894                    NaN                             No
# 1895                    NaN                             No
# 1896                    NaN                             No
#
#      Indian Entity (NAI Status) HRS Score Federal Facility Indicator  \
# 0                           NaN     28.90                         No
# 1                           NaN       NaN                         No
# 2                           NaN     50.00                         No
# 3                           NaN     50.00                         No
# 4                           NaN     50.00                         No
# ...                         ...       ...                        ...
# 1892                        NaN     47.70                         No
# 1893                        NaN     32.24                        Yes
# 1894                        NaN     35.59                         No
# 1895                        NaN     51.91                         No
# 1896                        NaN     50.00                         No
#
#                             Alias/Alternative Site Name Non-NPL Status Date  \
# 0     10TH STREET SITE, COLUMBUS PUBLIC WATER SUPPLY...          02/13/1987
# 1     29TH & MEAD GROUND WATER CONTAMINATION, 29TH &...          01/01/1996
# 2     35TH AVENUE COKE SITE, 35TH AVENUE SITE, WALTE...          09/22/2014
# 3     57TH AND N. BROADWAY STREETS SITE, 57TH AND NO...          02/04/1987
# 4     68TH STREET DUMP, 68TH STREET DUMP/INDUSTRIAL ...          04/30/2003
# ...                                                 ...                 ...
# 1892  PEIRCE DUMP, YORK OIL CO, YORK OIL CO., YORK O...          09/01/1980
# 1893  MARINE CORPS AIR STA, YUMA, MARINE CORPS AIR S...        [Blank Date]
# 1894       ZANESVILLE WELL FIELD, ZANESVILLE WELL FIELD          06/01/1982
# 1895  DRUM SVC CO OF FL, ZELLWOOD GROUND WATER CONTA...        [Blank Date]
# 1896           ZSCHIEGNER REFINING, ZSCHIEGNER REFINING          03/11/1994
#
#                         Superfund Site Profile Page URL  \
# 0                      www.epa.gov/superfund/10thstreet
# 1                     www.epa.gov/superfund/29thandmead
# 2                     www.epa.gov/superfund/35th-avenue
# 3                 www.epa.gov/superfund/57thandbroadway
# 4                      www.epa.gov/superfund/68thstreet
# ...                                                 ...
# 1892                     www.epa.gov/superfund/york-oil
# 1893                     www.epa.gov/superfund/yumausmc
# 1894         www.epa.gov/superfund/zanesville-wellfield
# 1895  www.epa.gov/superfund/zellwood-groundwater-con...
# 1896          www.epa.gov/superfund/zschiegner-refining
#
#      RCRA Handler ID - RCRA Handler Name
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 1892                                 NaN
# 1893                                 NaN
# 1894                                 NaN
# 1895                                 NaN
# 1896                                 NaN
#
# [1897 rows x 31 columns]

# %%
sites = superfund[superfund["State"]=="IL"]
sites.index = pd.Index(range(0, len(sites)))

# %%
sites["County"] = [sites['County'][i].capitalize() for i in range(len(sites))]
# Out:
# /tmp/ipykernel_59372/4057664734.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sites["County"] = [sites['County'][i].capitalize() for i in range(len(sites))]

# %%
test3 = [illinois[sites["County"][i]==illinois["NAME"]] for i in range(len(sites))]
test3 = [test3[i].iloc[:, :2] for i in range(len(test3))]
test3
# Out:
# [                        Geo Point  \
#  56  39.2733468255, -88.2401981662
#
#                                              Geo Shape
#  56  {"coordinates": [[[-88.471139, 39.272968], [-8...  ,
#                          Geo Point  \
#  60  42.3362603021, -89.1608658488
#
#                                              Geo Shape
#  60  {"coordinates": [[[-89.398011, 42.375173], [-8...  ,
#                          Geo Point  \
#  50  41.8954290221, -87.6461407931
#
#                                              Geo Shape
#  50  {"coordinates": [[[-88.238186, 42.066985], [-8...  ,
#                          Geo Point  \
#  57  39.9879052609, -91.1884921409
#
#                                              Geo Shape
#  57  {"coordinates": [[[-91.424108, 39.93575], [-91...  ,
#  Empty DataFrame
#  Columns: [Geo Point, Geo Shape]
#  Index: [],
#                         Geo Point  \
#  7  41.4450504457, -87.9786458597
#
#                                             Geo Shape
#  7  {"coordinates": [[[-88.255348, 41.550089], [-8...  ,
#                          Geo Point  \
#  47  39.2310459341, -89.4788485523
#
#                                              Geo Shape
#  47  {"coordinates": [[[-89.700396, 39.435828], [-8...  ,
#  Empty DataFrame
#  Columns: [Geo Point, Geo Shape]
#  Index: [],
#                          Geo Point  \
#  60  42.3362603021, -89.1608658488
#
#                                              Geo Shape
#  60  {"coordinates": [[[-89.398011, 42.375173], [-8...  ,
#                          Geo Point  \
#  77  42.3230756866, -88.8233754157
#
#                                              Geo Shape
#  77  {"coordinates": [[[-88.940753, 42.41387], [-88...  ,
#                         Geo Point  \
#  4  42.0425663561, -89.3207266558
#
#                                             Geo Shape
#  4  {"coordinates": [[[-89.685984, 42.112009], [-8...  ,
#                          Geo Point  \
#  35  39.5458317531, -89.2772543125
#
#                                              Geo Shape
#  35  {"coordinates": [[[-89.255282, 39.814716], [-8...  ,
#                        Geo Point  \
#  85  38.8297122608, -89.90499843
#
#                                              Geo Shape
#  85  {"coordinates": [[[-90.110007, 38.833548], [-9...  ,
#                          Geo Point  \
#  17  38.6064621876, -89.4224823889
#
#                                              Geo Shape
#  17  {"coordinates": [[[-89.705605, 38.567913], [-8...  ,
#                          Geo Point  \
#  75  41.1377184724, -87.8618317846
#
#                                              Geo Shape
#  75  {"coordinates": [[[-87.664806, 41.296823], [-8...  ,
#                         Geo Point  \
#  1  41.4041459264, -89.5286557577
#
#                                             Geo Shape
#  1  {"coordinates": [[[-89.856913, 41.408836], [-8...  ,
#  Empty DataFrame
#  Columns: [Geo Point, Geo Shape]
#  Index: [],
#                          Geo Point  \
#  47  39.2310459341, -89.4788485523
#
#                                              Geo Shape
#  47  {"coordinates": [[[-89.700396, 39.435828], [-8...  ,
#  Empty DataFrame
#  Columns: [Geo Point, Geo Shape]
#  Index: [],
#                          Geo Point  \
#  50  41.8954290221, -87.6461407931
#
#                                              Geo Shape
#  50  {"coordinates": [[[-88.238186, 42.066985], [-8...  ,
#                          Geo Point  \
#  60  42.3362603021, -89.1608658488
#
#                                              Geo Shape
#  60  {"coordinates": [[[-89.398011, 42.375173], [-8...  ,
#                          Geo Point  \
#  53  40.9318279821, -90.2132382621
#
#                                              Geo Shape
#  53  {"coordinates": [[[-90.440524, 40.97649], [-90...  ,
#                        Geo Point  \
#  6  42.325322722, -87.6311845438
#
#                                             Geo Shape
#  6  {"coordinates": [[[-88.198601, 42.415567], [-8...  ,
#                        Geo Point  \
#  73  40.183401621, -87.732815214
#
#                                              Geo Shape
#  73  {"coordinates": [[[-87.929442, 40.269693], [-8...  ,
#                         Geo Point  \
#  91  37.191593361, -89.3376041231
#
#                                              Geo Shape
#  91  {"coordinates": [[[-89.199751, 37.088868], [-8...  ,
#                          Geo Point  \
#  45  38.7199480156, -87.7267298383
#
#                                              Geo Shape
#  45  {"coordinates": [[[-87.759592, 38.849514], [-8...  ,
#                          Geo Point  \
#  60  42.3362603021, -89.1608658488
#
#                                              Geo Shape
#  60  {"coordinates": [[[-89.398011, 42.375173], [-8...  ,
#                        Geo Point  \
#  85  38.8297122608, -89.90499843
#
#                                              Geo Shape
#  85  {"coordinates": [[[-90.110007, 38.833548], [-9...  ,
#                        Geo Point  \
#  6  42.325322722, -87.6311845438
#
#                                             Geo Shape
#  6  {"coordinates": [[[-88.198601, 42.415567], [-8...  ,
#                         Geo Point  \
#  7  41.4450504457, -87.9786458597
#
#                                             Geo Shape
#  7  {"coordinates": [[[-88.255348, 41.550089], [-8...  ,
#                         Geo Point  \
#  7  41.4450504457, -87.9786458597
#
#                                             Geo Shape
#  7  {"coordinates": [[[-88.255348, 41.550089], [-8...  ,
#  Empty DataFrame
#  Columns: [Geo Point, Geo Shape]
#  Index: [],
#  Empty DataFrame
#  Columns: [Geo Point, Geo Shape]
#  Index: [],
#  Empty DataFrame
#  Columns: [Geo Point, Geo Shape]
#  Index: [],
#  Empty DataFrame
#  Columns: [Geo Point, Geo Shape]
#  Index: [],
#                          Geo Point  \
#  50  41.8954290221, -87.6461407931
#
#                                              Geo Shape
#  50  {"coordinates": [[[-88.238186, 42.066985], [-8...  ,
#  Empty DataFrame
#  Columns: [Geo Point, Geo Shape]
#  Index: [],
#  Empty DataFrame
#  Columns: [Geo Point, Geo Shape]
#  Index: [],
#  Empty DataFrame
#  Columns: [Geo Point, Geo Shape]
#  Index: [],
#                          Geo Point  \
#  77  42.3230756866, -88.8233754157
#
#                                              Geo Shape
#  77  {"coordinates": [[[-88.940753, 42.41387], [-88...  ,
#                        Geo Point  \
#  85  38.8297122608, -89.90499843
#
#                                              Geo Shape
#  85  {"coordinates": [[[-90.110007, 38.833548], [-9...  ,
#                        Geo Point  \
#  6  42.325322722, -87.6311845438
#
#                                             Geo Shape
#  6  {"coordinates": [[[-88.198601, 42.415567], [-8...  ,
#                        Geo Point  \
#  6  42.325322722, -87.6311845438
#
#                                             Geo Shape
#  6  {"coordinates": [[[-88.198601, 42.415567], [-8...  ,
#  Empty DataFrame
#  Columns: [Geo Point, Geo Shape]
#  Index: [],
#  Empty DataFrame
#  Columns: [Geo Point, Geo Shape]
#  Index: [],
#  Empty DataFrame
#  Columns: [Geo Point, Geo Shape]
#  Index: [],
#                        Geo Point  \
#  6  42.325322722, -87.6311845438
#
#                                             Geo Shape
#  6  {"coordinates": [[[-88.198601, 42.415567], [-8...  ,
#                          Geo Point  \
#  60  42.3362603021, -89.1608658488
#
#                                              Geo Shape
#  60  {"coordinates": [[[-89.398011, 42.375173], [-8...  ,
#                          Geo Point  \
#  77  42.3230756866, -88.8233754157
#
#                                              Geo Shape
#  77  {"coordinates": [[[-88.940753, 42.41387], [-88...  ,
#                          Geo Point  \
#  50  41.8954290221, -87.6461407931
#
#                                              Geo Shape
#  50  {"coordinates": [[[-88.238186, 42.066985], [-8...  ,
#                          Geo Point  \
#  50  41.8954290221, -87.6461407931
#
#                                              Geo Shape
#  50  {"coordinates": [[[-88.238186, 42.066985], [-8...  ,
#                          Geo Point  \
#  50  41.8954290221, -87.6461407931
#
#                                              Geo Shape
#  50  {"coordinates": [[[-88.238186, 42.066985], [-8...  ,
#                          Geo Point  \
#  50  41.8954290221, -87.6461407931
#
#                                              Geo Shape
#  50  {"coordinates": [[[-88.238186, 42.066985], [-8...  ,
#                          Geo Point  \
#  50  41.8954290221, -87.6461407931
#
#                                              Geo Shape
#  50  {"coordinates": [[[-88.238186, 42.066985], [-8...  ,
#                          Geo Point  \
#  50  41.8954290221, -87.6461407931
#
#                                              Geo Shape
#  50  {"coordinates": [[[-88.238186, 42.066985], [-8...  ,
#                          Geo Point  \
#  50  41.8954290221, -87.6461407931
#
#                                              Geo Shape
#  50  {"coordinates": [[[-88.238186, 42.066985], [-8...  ,
#                          Geo Point  \
#  50  41.8954290221, -87.6461407931
#
#                                              Geo Shape
#  50  {"coordinates": [[[-88.238186, 42.066985], [-8...  ,
#                        Geo Point  \
#  6  42.325322722, -87.6311845438
#
#                                             Geo Shape
#  6  {"coordinates": [[[-88.198601, 42.415567], [-8...  ,
#                          Geo Point  \
#  52  38.6495781117, -88.9189811153
#
#                                              Geo Shape
#  52  {"coordinates": [[[-88.807644, 38.82446], [-88...  ,
#                          Geo Point  \
#  13  37.7302529228, -88.9299244512
#
#                                              Geo Shape
#  13  {"coordinates": [[[-89.151677, 37.773956], [-8...  ,
#  Empty DataFrame
#  Columns: [Geo Point, Geo Shape]
#  Index: [],
#  Empty DataFrame
#  Columns: [Geo Point, Geo Shape]
#  Index: [],
#  Empty DataFrame
#  Columns: [Geo Point, Geo Shape]
#  Index: [],
#                          Geo Point  \
#  50  41.8954290221, -87.6461407931
#
#                                              Geo Shape
#  50  {"coordinates": [[[-88.238186, 42.066985], [-8...  ,
#                          Geo Point  \
#  60  42.3362603021, -89.1608658488
#
#                                              Geo Shape
#  60  {"coordinates": [[[-89.398011, 42.375173], [-8...  ,
#                          Geo Point  \
#  40  41.9388566679, -88.4286377038
#
#                                              Geo Shape
#  40  {"coordinates": [[[-88.601289, 41.981473], [-8...  ,
#                          Geo Point  \
#  86  39.3335754723, -87.7877174066
#
#                                              Geo Shape
#  86  {"coordinates": [[[-88.011728, 39.349837], [-8...  ,
#                        Geo Point  \
#  6  42.325322722, -87.6311845438
#
#                                             Geo Shape
#  6  {"coordinates": [[[-88.198601, 42.415567], [-8...  ,
#  Empty DataFrame
#  Columns: [Geo Point, Geo Shape]
#  Index: [],
#                        Geo Point  \
#  6  42.325322722, -87.6311845438
#
#                                             Geo Shape
#  6  {"coordinates": [[[-88.198601, 42.415567], [-8...  ]

# %%
illinois.iloc[:, [0,1,3]]
# Out:
#                          Geo Point  \
# 0    39.0855054887, -90.3565282985
# 1    41.4041459264, -89.5286557577
# 2    41.2044899818, -89.2857803179
# 3    40.2396222297, -89.9168137955
# 4    42.0425663561, -89.3207266558
# ..                             ...
# 97   39.0001785652, -89.0241202321
# 98   41.3440027805, -88.8859379256
# 99   40.7880635936, -89.7599800409
# 100  40.4037747348, -91.1646955496
# 101   40.4908916187, -88.847324278
#
#                                              Geo Shape  COUNTYFP
# 0    {"coordinates": [[[-90.592165, 39.086765], [-9...        83
# 1    {"coordinates": [[[-89.856913, 41.408836], [-8...        11
# 2    {"coordinates": [[[-89.333027, 41.132961], [-8...       155
# 3    {"coordinates": [[[-90.114921, 40.245482], [-9...       125
# 4    {"coordinates": [[[-89.685984, 42.112009], [-8...       141
# ..                                                 ...       ...
# 97   {"coordinates": [[[-89.250603, 39.152012], [-8...        51
# 98   {"coordinates": [[[-89.166473, 41.541697], [-8...        99
# 99   {"coordinates": [[[-89.985333, 40.800074], [-8...       143
# 100  {"coordinates": [[[-91.374208, 40.463993], [-9...        67
# 101  {"coordinates": [[[-89.266499, 40.485552], [-8...       113
#
# [102 rows x 3 columns]

# %%
illinois = illinois.sort_values(by=['COUNTYFP'])
illinois.index = pd.Index(range(len(illinois)))
illinois
# Out:
#                          Geo Point  \
# 0    39.9879052609, -91.1884921409
# 1     37.191593361, -89.3376041231
# 2    38.8868296401, -89.4355442381
# 3    42.3230756866, -88.8233754157
# 4    39.9617616288, -90.7503556212
# ..                             ...
# 97   41.7562548803, -89.9141029918
# 98   41.4450504457, -87.9786458597
# 99   37.7302529228, -88.9299244512
# 100  42.3362603021, -89.1608658488
# 101  40.7882358798, -89.2111061648
#
#                                              Geo Shape  STATEFP  COUNTYFP  \
# 0    {"coordinates": [[[-91.424108, 39.93575], [-91...       17         1
# 1    {"coordinates": [[[-89.199751, 37.088868], [-8...       17         3
# 2    {"coordinates": [[[-89.361793, 39.027724], [-8...       17         5
# 3    {"coordinates": [[[-88.940753, 42.41387], [-88...       17         7
# 4    {"coordinates": [[[-90.914687, 40.018039], [-9...       17         9
# ..                                                 ...      ...       ...
# 97   {"coordinates": [[[-90.181788, 41.843538], [-9...       17       195
# 98   {"coordinates": [[[-88.255348, 41.550089], [-8...       17       197
# 99   {"coordinates": [[[-89.151677, 37.773956], [-8...       17       199
# 100  {"coordinates": [[[-89.398011, 42.375173], [-8...       17       201
# 101  {"coordinates": [[[-89.047718, 40.925749], [-8...       17       203
#
#      COUNTYNS  GEOID        NAME           NAMELSAD STUSAB  LSAD  ...  \
# 0      424202  17001       Adams       Adams County     IL     6  ...
# 1      424203  17003   Alexander   Alexander County     IL     6  ...
# 2      424204  17005        Bond        Bond County     IL     6  ...
# 3      424205  17007       Boone       Boone County     IL     6  ...
# 4      424206  17009       Brown       Brown County     IL     6  ...
# ..        ...    ...         ...                ...    ...   ...  ...
# 97    1785167  17195   Whiteside   Whiteside County     IL     6  ...
# 98    1785190  17197        Will        Will County     IL     6  ...
# 99    1785215  17199  Williamson  Williamson County     IL     6  ...
# 100   1785216  17201   Winnebago   Winnebago County     IL     6  ...
# 101   1785231  17203    Woodford    Woodford County     IL     6  ...
#
#       CBSAFP METDIVFP  FUNCSTAT       ALAND    AWATER     INTPTLAT  \
# 0    39500.0      NaN         A  2214804481  41776031  +39.9860525
# 1    16020.0      NaN         A   609667772  44539209  +37.1836583
# 2    41180.0      NaN         A   985073265   6462629  +38.8859240
# 3    40420.0      NaN         A   727180620   3363818  +42.3189831
# 4        NaN      NaN         A   791828628   4144346  +39.9620694
# ..       ...      ...       ...         ...       ...          ...
# 97   44580.0      NaN         A  1771808919  31883752  +41.7506733
# 98   16980.0  16984.0         A  2164895527  34582450  +41.4484742
# 99   16060.0      NaN         A  1088349246  62460141  +37.7303533
# 100  40420.0      NaN         A  1329068433  15598347  +42.3373957
# 101  37900.0      NaN         A  1366821840  38477370  +40.7897870
#
#          INTPTLON  STATE_NAME COUNTYFP NOZERO   FIPS
# 0    -091.1949607    Illinois               1  17001
# 1    -089.3495158    Illinois               3  17003
# 2    -089.4365916    Illinois               5  17005
# 3    -088.8242951    Illinois               7  17007
# 4    -090.7503095    Illinois               9  17009
# ..            ...         ...             ...    ...
# 97   -089.9110045    Illinois             195  17195
# 98   -087.9784564    Illinois             197  17197
# 99   -088.9300182    Illinois             199  17199
# 100  -089.1612053    Illinois             201  17201
# 101  -089.2105871    Illinois             203  17203
#
# [102 rows x 23 columns]

# %%
set(sites["County"])
# Out:
# {'Adams',
#  'Alexander',
#  'Boone',
#  'Bureau',
#  'Christian',
#  'Clark',
#  'Clinton',
#  'Cook',
#  'Cumberland',
#  'Dupage',
#  'Jo daviess',
#  'Kane',
#  'Kankakee',
#  'Knox',
#  'La salle',
#  'Lake',
#  'Lawrence',
#  'Madison',
#  'Marion',
#  'Mchenry',
#  'Montgomery',
#  'Ogle',
#  'St. clair',
#  'Vermilion',
#  'Will',
#  'Williamson',
#  'Winnebago'}

# %%
sites.to_csv("illinois_sites.csv")

# %%
test4 = pd.read_csv("racial.csv")
test4 = test4[test4["COUNTY"] != 0]
test4.index = pd.Index(range(len(test4)))

# %%
test4['FIPS'] = [(str(int(test4["STATE"][i])//10)+str(int(test4["STATE"][i])%10)+str(int(test4["COUNTY"][i])//100)+str(int(test4["COUNTY"][i])//10%10)+str(int(test4["COUNTY"][i])%10)) for i in range(0, len(test4))]

# %%
test4.to_csv("racial_fips3.csv")

# %%
test4
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         50       3         6      1       1  Alabama     Autauga County
# 1         50       3         6      1       3  Alabama     Baldwin County
# 2         50       3         6      1       5  Alabama     Barbour County
# 3         50       3         6      1       7  Alabama        Bibb County
# 4         50       3         6      1       9  Alabama      Blount County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3138      50       4         8     56      37  Wyoming  Sweetwater County
# 3139      50       4         8     56      39  Wyoming       Teton County
# 3140      50       4         8     56      41  Wyoming       Uinta County
# 3141      50       4         8     56      43  Wyoming    Washakie County
# 3142      50       4         8     56      45  Wyoming      Weston County
#
#       ESTIMATESBASE2020  POPESTIMATE2020  POPESTIMATE2021  ...  \
# 0                 58805            58877            59095  ...
# 1                231767           233140           239294  ...
# 2                 25223            25180            24964  ...
# 3                 22293            22223            22477  ...
# 4                 59134            59081            59041  ...
# ...                 ...              ...              ...  ...
# 3138              42272            42158            41614  ...
# 3139              23331            23347            23575  ...
# 3140              20450            20441            20635  ...
# 3141               7685             7658             7705  ...
# 3142               6838             6809             6745  ...
#
#       GQESTIMATESBASE2020  GQESTIMATES2020  GQESTIMATES2021  RBIRTH2021  \
# 0                     442              442              442   11.002611
# 1                    2177             2177             2177    9.567474
# 2                    2789             2789             2789   10.928526
# 3                    2062             2062             2062   10.111857
# 4                     449              449              449   10.650006
# ...                   ...              ...              ...         ...
# 3138                  720              720              720   11.483551
# 3139                  215              215              215    9.377264
# 3140                  187              187              187   11.003993
# 3141                  119              119              119    9.893901
# 3142                  300              300              300    7.673012
#
#       RDEATH2021  RNATURALCHG2021  RINTERNATIONALMIG2021  RDOMESTICMIG2021  \
# 0      11.545112        -0.542502               0.084766          4.017903
# 1      12.137145        -2.569671               0.266704         28.702422
# 2      15.714742        -4.786216               0.039885         -3.908743
# 3      12.617450        -2.505593               0.089485         13.825503
# 4      13.883950        -3.233945               0.033863          2.370431
# ...          ...              ...                    ...               ...
# 3138    9.549730         1.933820               0.429738        -15.255694
# 3139    4.091897         5.285367               0.340991          4.049273
# 3140    8.082579         2.921414               0.146071          6.378420
# 3141   14.971034        -5.077133               0.000000         11.325913
# 3142   13.280212        -5.607201               0.000000         -3.984064
#
#       RNETMIG2021   FIPS
# 0        4.102668  01001
# 1       28.969126  01003
# 2       -3.868858  01005
# 3       13.914989  01007
# 4        2.404294  01009
# ...           ...    ...
# 3138   -14.825956  56037
# 3139     4.390265  56039
# 3140     6.524491  56041
# 3141    11.325913  56043
# 3142    -3.984064  56045
#
# [3143 rows x 36 columns]

# %%
test["Geo Shape"]
# Out:
# 0       {"coordinates": [[[-98.273667, 40.089399], [-9...
# 1       {"coordinates": [[[-84.397189, 40.786584], [-8...
# 2       {"coordinates": [[[-81.488643, 41.631522], [-8...
# 3       {"coordinates": [[[-94.617088, 37.477776], [-9...
# 4       {"coordinates": [[[-85.561745, 44.952258], [-8...
#                               ...
# 3228    {"coordinates": [[[-82.455197, 38.844579], [-8...
# 3229    {"coordinates": [[[-85.415774, 31.490413], [-8...
# 3230    {"coordinates": [[[-94.612713, 38.313115], [-9...
# 3231    {"coordinates": [[[-90.093625, 32.707628], [-9...
# 3232    {"coordinates": [[[-101.692269, 32.271062], [-...
# Name: Geo Shape, Length: 3233, dtype: object

# %%
races = pd.read_excel("illinois_racial.xlsx",header=None).T
races
# Out:
#                               0        1                        2   \
# 0                          Label   Total:  Population of one race:
# 1         Adams County, Illinois   65,737                   62,520
# 2     Alexander County, Illinois    5,240                    4,978
# 3          Bond County, Illinois   16,725                   16,051
# 4         Boone County, Illinois   53,448                   47,368
# ..                           ...      ...                      ...
# 98    Whiteside County, Illinois   55,691                   51,290
# 99         Will County, Illinois  696,355                  625,921
# 100  Williamson County, Illinois   67,153                   63,369
# 101   Winnebago County, Illinois  285,350                  259,097
# 102    Woodford County, Illinois   38,467                   36,872
#
#               3                                4   \
# 0    White alone  Black or African American alone
# 1         58,837                            2,501
# 2          3,311                            1,617
# 3         14,446                            1,077
# 4         38,766                            1,245
# ..           ...                              ...
# 98        47,759                              839
# 99       443,562                           80,979
# 100       58,897                            2,870
# 101      191,124                           39,159
# 102       36,102                              278
#
#                                           5            6   \
# 0    American Indian and Alaska Native alone  Asian alone
# 1                                        104          513
# 2                                         24            6
# 3                                         52          105
# 4                                        498          659
# ..                                       ...          ...
# 98                                       235          311
# 99                                     3,974       42,849
# 100                                      263          776
# 101                                    1,632        8,039
# 102                                       49          217
#
#                                                    7                      8   \
# 0    Native Hawaiian and Other Pacific Islander alone  Some Other Race alone
# 1                                                  39                    526
# 2                                                   0                     20
# 3                                                  11                    360
# 4                                                  24                  6,176
# ..                                                ...                    ...
# 98                                                 12                  2,134
# 99                                                126                 54,431
# 100                                                 9                    554
# 101                                                84                 19,059
# 102                                                14                    212
#
#                                    9   ...  \
# 0    Population of two or more races:  ...
# 1                               3,217  ...
# 2                                 262  ...
# 3                                 674  ...
# 4                               6,080  ...
# ..                                ...  ...
# 98                              4,401  ...
# 99                             70,434  ...
# 100                             3,784  ...
# 101                            26,253  ...
# 102                             1,595  ...
#
#                                                     62  \
# 0    American Indian and Alaska Native; Asian; Nati...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 98                                                   0
# 99                                                   0
# 100                                                  0
# 101                                                  0
# 102                                                  0
#
#                             63  \
# 0    Population of five races:
# 1                            0
# 2                            0
# 3                            0
# 4                            4
# ..                         ...
# 98                           0
# 99                          11
# 100                          0
# 101                          6
# 102                          3
#
#                                                     64  \
# 0    White; Black or African American; American Ind...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    4
# ..                                                 ...
# 98                                                   0
# 99                                                   4
# 100                                                  0
# 101                                                  0
# 102                                                  2
#
#                                                     65  \
# 0    White; Black or African American; American Ind...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 98                                                   0
# 99                                                   7
# 100                                                  0
# 101                                                  0
# 102                                                  1
#
#                                                     66  \
# 0    White; Black or African American; American Ind...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 98                                                   0
# 99                                                   0
# 100                                                  0
# 101                                                  0
# 102                                                  0
#
#                                                     67  \
# 0    White; Black or African American; Asian; Nativ...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 98                                                   0
# 99                                                   0
# 100                                                  0
# 101                                                  6
# 102                                                  0
#
#                                                     68  \
# 0    White; American Indian and Alaska Native; Asia...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 98                                                   0
# 99                                                   0
# 100                                                  0
# 101                                                  0
# 102                                                  0
#
#                                                     69  \
# 0    Black or African American; American Indian and...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 98                                                   0
# 99                                                   0
# 100                                                  0
# 101                                                  0
# 102                                                  0
#
#                            70  \
# 0    Population of six races:
# 1                           0
# 2                           0
# 3                           0
# 4                           0
# ..                        ...
# 98                          0
# 99                          4
# 100                         4
# 101                         2
# 102                         0
#
#                                                     71
# 0    White; Black or African American; American Ind...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 98                                                   0
# 99                                                   4
# 100                                                  4
# 101                                                  2
# 102                                                  0
#
# [103 rows x 72 columns]

# %%
races.columns = races.iloc[0]
races = races.drop(0)

# %%
races = races.rename(columns={"Total:":"Total Pop", "White alone":"White Pop","Label":"County"})
races.index = pd.Index(range(len(races)))
races
# Out:
# 0                         County Total Pop Population of one race: White Pop  \
# 0         Adams County, Illinois    65,737                  62,520    58,837
# 1     Alexander County, Illinois     5,240                   4,978     3,311
# 2          Bond County, Illinois    16,725                  16,051    14,446
# 3         Boone County, Illinois    53,448                  47,368    38,766
# 4         Brown County, Illinois     6,244                   6,066     4,779
# ..                           ...       ...                     ...       ...
# 97    Whiteside County, Illinois    55,691                  51,290    47,759
# 98         Will County, Illinois   696,355                 625,921   443,562
# 99   Williamson County, Illinois    67,153                  63,369    58,897
# 100   Winnebago County, Illinois   285,350                 259,097   191,124
# 101    Woodford County, Illinois    38,467                  36,872    36,102
#
# 0   Black or African American alone American Indian and Alaska Native alone  \
# 0                             2,501                                     104
# 1                             1,617                                      24
# 2                             1,077                                      52
# 3                             1,245                                     498
# 4                             1,054                                      11
# ..                              ...                                     ...
# 97                              839                                     235
# 98                           80,979                                   3,974
# 99                            2,870                                     263
# 100                          39,159                                   1,632
# 101                             278                                      49
#
# 0   Asian alone Native Hawaiian and Other Pacific Islander alone  \
# 0           513                                               39
# 1             6                                                0
# 2           105                                               11
# 3           659                                               24
# 4            12                                                0
# ..          ...                                              ...
# 97          311                                               12
# 98       42,849                                              126
# 99          776                                                9
# 100       8,039                                               84
# 101         217                                               14
#
# 0   Some Other Race alone Population of two or more races:  ...  \
# 0                     526                            3,217  ...
# 1                      20                              262  ...
# 2                     360                              674  ...
# 3                   6,176                            6,080  ...
# 4                     210                              178  ...
# ..                    ...                              ...  ...
# 97                  2,134                            4,401  ...
# 98                 54,431                           70,434  ...
# 99                    554                            3,784  ...
# 100                19,059                           26,253  ...
# 101                   212                            1,595  ...
#
# 0   American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 97                                                   0
# 98                                                   0
# 99                                                   0
# 100                                                  0
# 101                                                  0
#
# 0   Population of five races:  \
# 0                           0
# 1                           0
# 2                           0
# 3                           4
# 4                           1
# ..                        ...
# 97                          0
# 98                         11
# 99                          0
# 100                         6
# 101                         3
#
# 0   White; Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    4
# 4                                                    0
# ..                                                 ...
# 97                                                   0
# 98                                                   4
# 99                                                   0
# 100                                                  0
# 101                                                  2
#
# 0   White; Black or African American; American Indian and Alaska Native; Asian; Some Other Race  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 97                                                   0
# 98                                                   7
# 99                                                   0
# 100                                                  0
# 101                                                  1
#
# 0   White; Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    1
# ..                                                 ...
# 97                                                   0
# 98                                                   0
# 99                                                   0
# 100                                                  0
# 101                                                  0
#
# 0   White; Black or African American; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 97                                                   0
# 98                                                   0
# 99                                                   0
# 100                                                  6
# 101                                                  0
#
# 0   White; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 97                                                   0
# 98                                                   0
# 99                                                   0
# 100                                                  0
# 101                                                  0
#
# 0   Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 97                                                   0
# 98                                                   0
# 99                                                   0
# 100                                                  0
# 101                                                  0
#
# 0   Population of six races:  \
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ..                       ...
# 97                         0
# 98                         4
# 99                         4
# 100                        2
# 101                        0
#
# 0   White; Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 97                                                   0
# 98                                                   4
# 99                                                   4
# 100                                                  2
# 101                                                  0
#
# [102 rows x 72 columns]

# %%
races["County"] = [races["County"][i][:-10] for i in range(len(races))]

# %%
races["County"][1]
# Out:
# 'Alexander County'

# %%
races["Total Pop"] = [int(races["Total Pop"][i].replace(",","")) for i in range(len(races))]
races["White Pop"] = [int(races["White Pop"][i].replace(",","")) for i in range(len(races))]
races["Black or African American alone"] = [int(races["Black or African American alone"][i].replace(",","")) for i in range(len(races))]

# %%
races["Percent Not White"] = pd.Series((races["Total Pop"]-races["White Pop"])/races["Total Pop"]*100//1, name="Percent Not White")
races["Percent Black"] = pd.Series((races["Black or African American alone"])/races["Total Pop"]*100//1, name="Percent Not White")

# %%
test5 = races[["County", "Percent Not White"]]

# %%
illinois["Percent Not White"] = races["Percent Not White"]
illinois["Percent Black"] = races["Percent Black"]

# %%
illinois[["FIPS","NAMELSAD", "Percent Not White", "Percent Black"]].to_csv("percents_fips.csv")

# %%
illinois
# Out:
#                          Geo Point  \
# 0    39.9879052609, -91.1884921409
# 1     37.191593361, -89.3376041231
# 2    38.8868296401, -89.4355442381
# 3    42.3230756866, -88.8233754157
# 4    39.9617616288, -90.7503556212
# ..                             ...
# 97   41.7562548803, -89.9141029918
# 98   41.4450504457, -87.9786458597
# 99   37.7302529228, -88.9299244512
# 100  42.3362603021, -89.1608658488
# 101  40.7882358798, -89.2111061648
#
#                                              Geo Shape  STATEFP  COUNTYFP  \
# 0    {"coordinates": [[[-91.424108, 39.93575], [-91...       17         1
# 1    {"coordinates": [[[-89.199751, 37.088868], [-8...       17         3
# 2    {"coordinates": [[[-89.361793, 39.027724], [-8...       17         5
# 3    {"coordinates": [[[-88.940753, 42.41387], [-88...       17         7
# 4    {"coordinates": [[[-90.914687, 40.018039], [-9...       17         9
# ..                                                 ...      ...       ...
# 97   {"coordinates": [[[-90.181788, 41.843538], [-9...       17       195
# 98   {"coordinates": [[[-88.255348, 41.550089], [-8...       17       197
# 99   {"coordinates": [[[-89.151677, 37.773956], [-8...       17       199
# 100  {"coordinates": [[[-89.398011, 42.375173], [-8...       17       201
# 101  {"coordinates": [[[-89.047718, 40.925749], [-8...       17       203
#
#      COUNTYNS  GEOID        NAME           NAMELSAD STUSAB  LSAD  ...  \
# 0      424202  17001       Adams       Adams County     IL     6  ...
# 1      424203  17003   Alexander   Alexander County     IL     6  ...
# 2      424204  17005        Bond        Bond County     IL     6  ...
# 3      424205  17007       Boone       Boone County     IL     6  ...
# 4      424206  17009       Brown       Brown County     IL     6  ...
# ..        ...    ...         ...                ...    ...   ...  ...
# 97    1785167  17195   Whiteside   Whiteside County     IL     6  ...
# 98    1785190  17197        Will        Will County     IL     6  ...
# 99    1785215  17199  Williamson  Williamson County     IL     6  ...
# 100   1785216  17201   Winnebago   Winnebago County     IL     6  ...
# 101   1785231  17203    Woodford    Woodford County     IL     6  ...
#
#     FUNCSTAT       ALAND    AWATER     INTPTLAT      INTPTLON STATE_NAME  \
# 0          A  2214804481  41776031  +39.9860525  -091.1949607   Illinois
# 1          A   609667772  44539209  +37.1836583  -089.3495158   Illinois
# 2          A   985073265   6462629  +38.8859240  -089.4365916   Illinois
# 3          A   727180620   3363818  +42.3189831  -088.8242951   Illinois
# 4          A   791828628   4144346  +39.9620694  -090.7503095   Illinois
# ..       ...         ...       ...          ...           ...        ...
# 97         A  1771808919  31883752  +41.7506733  -089.9110045   Illinois
# 98         A  2164895527  34582450  +41.4484742  -087.9784564   Illinois
# 99         A  1088349246  62460141  +37.7303533  -088.9300182   Illinois
# 100        A  1329068433  15598347  +42.3373957  -089.1612053   Illinois
# 101        A  1366821840  38477370  +40.7897870  -089.2105871   Illinois
#
#      COUNTYFP NOZERO   FIPS Percent Not White Percent Black
# 0                  1  17001              10.0           3.0
# 1                  3  17003              36.0          30.0
# 2                  5  17005              13.0           6.0
# 3                  7  17007              27.0           2.0
# 4                  9  17009              23.0          16.0
# ..               ...    ...               ...           ...
# 97               195  17195              14.0           1.0
# 98               197  17197              36.0          11.0
# 99               199  17199              12.0           4.0
# 100              201  17201              33.0          13.0
# 101              203  17203               6.0           0.0
#
# [102 rows x 25 columns]

# %%
races
# Out:
# 0               County  Total Pop Population of one race:  White Pop  \
# 0         Adams County      65737                  62,520      58837
# 1     Alexander County       5240                   4,978       3311
# 2          Bond County      16725                  16,051      14446
# 3         Boone County      53448                  47,368      38766
# 4         Brown County       6244                   6,066       4779
# ..                 ...        ...                     ...        ...
# 97    Whiteside County      55691                  51,290      47759
# 98         Will County     696355                 625,921     443562
# 99   Williamson County      67153                  63,369      58897
# 100   Winnebago County     285350                 259,097     191124
# 101    Woodford County      38467                  36,872      36102
#
# 0    Black or African American alone American Indian and Alaska Native alone  \
# 0                               2501                                     104
# 1                               1617                                      24
# 2                               1077                                      52
# 3                               1245                                     498
# 4                               1054                                      11
# ..                               ...                                     ...
# 97                               839                                     235
# 98                             80979                                   3,974
# 99                              2870                                     263
# 100                            39159                                   1,632
# 101                              278                                      49
#
# 0   Asian alone Native Hawaiian and Other Pacific Islander alone  \
# 0           513                                               39
# 1             6                                                0
# 2           105                                               11
# 3           659                                               24
# 4            12                                                0
# ..          ...                                              ...
# 97          311                                               12
# 98       42,849                                              126
# 99          776                                                9
# 100       8,039                                               84
# 101         217                                               14
#
# 0   Some Other Race alone Population of two or more races:  ...  \
# 0                     526                            3,217  ...
# 1                      20                              262  ...
# 2                     360                              674  ...
# 3                   6,176                            6,080  ...
# 4                     210                              178  ...
# ..                    ...                              ...  ...
# 97                  2,134                            4,401  ...
# 98                 54,431                           70,434  ...
# 99                    554                            3,784  ...
# 100                19,059                           26,253  ...
# 101                   212                            1,595  ...
#
# 0   White; Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    4
# 4                                                    0
# ..                                                 ...
# 97                                                   0
# 98                                                   4
# 99                                                   0
# 100                                                  0
# 101                                                  2
#
# 0   White; Black or African American; American Indian and Alaska Native; Asian; Some Other Race  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 97                                                   0
# 98                                                   7
# 99                                                   0
# 100                                                  0
# 101                                                  1
#
# 0   White; Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    1
# ..                                                 ...
# 97                                                   0
# 98                                                   0
# 99                                                   0
# 100                                                  0
# 101                                                  0
#
# 0   White; Black or African American; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 97                                                   0
# 98                                                   0
# 99                                                   0
# 100                                                  6
# 101                                                  0
#
# 0   White; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 97                                                   0
# 98                                                   0
# 99                                                   0
# 100                                                  0
# 101                                                  0
#
# 0   Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 97                                                   0
# 98                                                   0
# 99                                                   0
# 100                                                  0
# 101                                                  0
#
# 0   Population of six races:  \
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ..                       ...
# 97                         0
# 98                         4
# 99                         4
# 100                        2
# 101                        0
#
# 0   White; Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 97                                                   0
# 98                                                   4
# 99                                                   4
# 100                                                  2
# 101                                                  0
#
# 0   Percent Not White Percent Black
# 0                10.0           3.0
# 1                36.0          30.0
# 2                13.0           6.0
# 3                27.0           2.0
# 4                23.0          16.0
# ..                ...           ...
# 97               14.0           1.0
# 98               36.0          11.0
# 99               12.0           4.0
# 100              33.0          13.0
# 101               6.0           0.0
#
# [102 rows x 74 columns]

# %%
with_sites = set(sites.County)

# %%
with_sites = {site:0 for site in with_sites}

# %%
with_sites
# Out:
# {'Marion': 0,
#  'La salle': 0,
#  'Alexander': 0,
#  'Dupage': 0,
#  'Mchenry': 0,
#  'Bureau': 0,
#  'Madison': 0,
#  'Cumberland': 0,
#  'Kankakee': 0,
#  'Jo daviess': 0,
#  'Ogle': 0,
#  'Boone': 0,
#  'Christian': 0,
#  'Knox': 0,
#  'St. clair': 0,
#  'Williamson': 0,
#  'Cook': 0,
#  'Lawrence': 0,
#  'Clark': 0,
#  'Adams': 0,
#  'Montgomery': 0,
#  'Clinton': 0,
#  'Vermilion': 0,
#  'Kane': 0,
#  'Winnebago': 0,
#  'Will': 0,
#  'Lake': 0}

# %%
for i in range(len(sites)):
    try:
        with_sites[sites["County"][i]] += 1
    except:
        continue

# %%
with_sites = {site+" County":with_sites[site] for site in with_sites}

# %%
with_sites
# Out:
# {'Marion County': 1,
#  'La salle County': 4,
#  'Alexander County': 1,
#  'Dupage County': 7,
#  'Mchenry County': 1,
#  'Bureau County': 1,
#  'Madison County': 3,
#  'Cumberland County': 1,
#  'Kankakee County': 1,
#  'Jo daviess County': 2,
#  'Ogle County': 1,
#  'Boone County': 3,
#  'Christian County': 1,
#  'Knox County': 1,
#  'St. clair County': 4,
#  'Williamson County': 1,
#  'Cook County': 12,
#  'Lawrence County': 1,
#  'Clark County': 1,
#  'Adams County': 1,
#  'Montgomery County': 2,
#  'Clinton County': 1,
#  'Vermilion County': 1,
#  'Kane County': 1,
#  'Winnebago County': 6,
#  'Will County': 3,
#  'Lake County': 8}

# %%
illinois["Superfund Sites"] = [0 for i in range(len(illinois))]
for i in range(len(illinois)):
    try:
        illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
    except:
        continue
# Out:
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]
# /tmp/ipykernel_59372/1610699587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois["Superfund Sites"][i] = with_sites[illinois["NAMELSAD"][i]]

# %%
illinois[["FIPS","NAMELSAD", "Superfund Sites"]].to_csv("sites_fips.csv")

# %%
incomes = pd.read_excel("income_data.xlsx")
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                               Label
# 2   HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATIN...
# 3                                          Households
# 4                                          One race--
# 5                                               White
# 6                           Black or African American
# 7                   American Indian and Alaska Native
# 8                                               Asian
# 9          Native Hawaiian and Other Pacific Islander
# 10                                    Some other race
# 11                                  Two or more races
# 12            Hispanic or Latino origin (of any race)
# 13                White alone, not Hispanic or Latino
# 14             HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER
# 15                                     15 to 24 years
# 16                                     25 to 44 years
# 17                                     45 to 64 years
# 18                                  65 years and over
# 19                                           FAMILIES
# 20                                           Families
# 21    With own children of householder under 18 years
# 22  With no own children of householder under 18 y...
# 23                            Married-couple families
# 24                   With own children under 18 years
# 25              Female householder, no spouse present
# 26                   With own children under 18 years
# 27                Male householder, no spouse present
# 28                   With own children under 18 years
# 29                       FAMILY INCOME BY FAMILY SIZE
# 30                                  2-person families
# 31                                  3-person families
# 32                                  4-person families
# 33                                  5-person families
# 34                                  6-person families
# 35                          7-or-more person families
# 36                 FAMILY INCOME BY NUMBER OF EARNERS
# 37                                         No earners
# 38                                           1 earner
# 39                                          2 earners
# 40                                  3 or more earners
# 41                               NONFAMILY HOUSEHOLDS
# 42                               Nonfamily households
# 43                                 Female householder
# 44                                       Living alone
# 45                                   Not living alone
# 46                                   Male householder
# 47                                       Living alone
# 48                                   Not living alone
#
#    Champaign County, Illinois       Unnamed: 2            Unnamed: 3  \
# 0                      Number              NaN  Percent Distribution
# 1                    Estimate  Margin of Error              Estimate
# 2                         NaN              NaN                   NaN
# 3                      84,713           ±1,628                84,713
# 4                         NaN              NaN                   NaN
# 5                      57,311           ±1,561                 67.7%
# 6                      12,479           ±1,352                 14.7%
# 7                           N                N                     N
# 8                       9,064           ±1,225                 10.7%
# 9                           N                N                     N
# 10                          N                N                     N
# 11                          N                N                     N
# 12                          N                N                     N
# 13                     56,244           ±1,581                 66.4%
# 14                        NaN              NaN                   NaN
# 15                     15,009           ±2,100                 17.7%
# 16                     27,864           ±1,898                 32.9%
# 17                     23,328           ±1,557                 27.5%
# 18                     18,512           ±1,218                 21.9%
# 19                        NaN              NaN                   NaN
# 20                     43,122           ±2,546                43,122
# 21                          N                N                     N
# 22                          N                N                     N
# 23                          N                N                     N
# 24                          N                N                     N
# 25                          N                N                     N
# 26                          N                N                     N
# 27                          N                N                     N
# 28                          N                N                     N
# 29                        NaN              NaN                   NaN
# 30                     23,704           ±2,141                 55.0%
# 31                      8,839           ±1,520                 20.5%
# 32                      6,969           ±1,509                 16.2%
# 33                      2,077             ±848                  4.8%
# 34                      1,189             ±852                  2.8%
# 35                        344             ±298                  0.8%
# 36                        NaN              NaN                   NaN
# 37                      7,283           ±1,293                 16.9%
# 38                     13,704           ±1,893                 31.8%
# 39                     19,409           ±1,936                 45.0%
# 40                      2,726             ±792                  6.3%
# 41                        NaN              NaN                   NaN
# 42                     41,591           ±2,630                41,591
# 43                     20,880           ±2,159                 50.2%
# 44                     15,241           ±2,059                 36.6%
# 45                      5,639           ±1,312                 13.6%
# 46                     20,711           ±2,040                 49.8%
# 47                     16,369           ±1,996                 39.4%
# 48                      4,342           ±1,122                 10.4%
#
#          Unnamed: 4               Unnamed: 5       Unnamed: 6  \
# 0               NaN  Median income (dollars)              NaN
# 1   Margin of Error                 Estimate  Margin of Error
# 2               NaN                      NaN              NaN
# 3            ±1,628                   60,168           ±3,187
# 4               NaN                      NaN              NaN
# 5              ±1.9                   71,017           ±5,604
# 6              ±1.5                   29,595           ±4,566
# 7                 N                        N                N
# 8              ±1.4                   50,328          ±23,862
# 9                 N                        -               **
# 10                N                        N                N
# 11                N                   73,051          ±19,712
# 12                N                   61,042          ±21,566
# 13             ±1.9                   71,243           ±6,009
# 14              NaN                      NaN              NaN
# 15             ±2.3                   19,864           ±5,094
# 16             ±2.2                   68,184           ±6,326
# 17             ±1.9                   81,317          ±16,760
# 18             ±1.5                   63,293           ±4,054
# 19              NaN                      NaN              NaN
# 20           ±2,546                   95,375           ±9,840
# 21                N                   84,795          ±10,336
# 22                N                  104,952          ±10,880
# 23                N                  114,987           ±5,159
# 24                N                  116,240           ±8,834
# 25                N                   29,571           ±4,262
# 26                N                   22,372           ±9,002
# 27                N                   52,038          ±19,975
# 28                N                   51,250          ±18,057
# 29              NaN                      NaN              NaN
# 30             ±3.9                   94,111          ±11,449
# 31             ±3.3                   99,269          ±26,378
# 32             ±3.4                   84,883          ±23,485
# 33             ±2.0                  168,221          ±85,237
# 34             ±2.0                   51,270          ±46,053
# 35             ±0.7                   74,184         ±188,620
# 36              NaN                      NaN              NaN
# 37             ±2.9                   70,220          ±16,015
# 38             ±3.7                   61,207           ±9,627
# 39             ±3.5                  116,393           ±4,914
# 40             ±1.9                  174,155          ±33,296
# 41              NaN                      NaN              NaN
# 42           ±2,630                   33,828           ±3,968
# 43             ±3.9                   34,227           ±4,193
# 44             ±3.8                   33,422           ±3,950
# 45             ±3.2                   40,757          ±24,896
# 46             ±3.9                   32,994           ±7,616
# 47             ±3.9                   25,964           ±5,144
# 48             ±2.8                   62,905          ±28,719
#
#    Cook County, Illinois       Unnamed: 8            Unnamed: 9  ...  \
# 0                 Number              NaN  Percent Distribution  ...
# 1               Estimate  Margin of Error              Estimate  ...
# 2                    NaN              NaN                   NaN  ...
# 3              2,110,498           ±7,570             2,110,498  ...
# 4                    NaN              NaN                   NaN  ...
# 5              1,046,143           ±7,958                 49.6%  ...
# 6                486,508           ±6,348                 23.1%  ...
# 7                 18,743           ±2,645                  0.9%  ...
# 8                158,955           ±4,935                  7.5%  ...
# 9                      N                N                     N  ...
# 10               190,862           ±7,311                  9.0%  ...
# 11               208,149           ±7,294                  9.9%  ...
# 12               418,567           ±7,241                 19.8%  ...
# 13               991,697           ±7,323                 47.0%  ...
# 14                   NaN              NaN                   NaN  ...
# 15                80,735           ±5,382                  3.8%  ...
# 16               764,618           ±7,614                 36.2%  ...
# 17               735,186           ±9,077                 34.8%  ...
# 18               529,959           ±5,041                 25.1%  ...
# 19                   NaN              NaN                   NaN  ...
# 20             1,206,811          ±13,796             1,206,811  ...
# 21               486,664          ±11,725                 40.3%  ...
# 22               720,147          ±11,767                 59.7%  ...
# 23               803,465          ±13,453                 66.6%  ...
# 24               311,189           ±9,296                 25.8%  ...
# 25               294,231          ±10,513                 24.4%  ...
# 26               134,302           ±7,592                 11.1%  ...
# 27               109,115           ±6,402                  9.0%  ...
# 28                41,173           ±4,475                  3.4%  ...
# 29                   NaN              NaN                   NaN  ...
# 30               522,734           ±9,937                 43.3%  ...
# 31               282,176          ±10,739                 23.4%  ...
# 32               236,288           ±8,921                 19.6%  ...
# 33               103,061           ±6,011                  8.5%  ...
# 34                37,940           ±3,679                  3.1%  ...
# 35                24,612           ±3,131                  2.0%  ...
# 36                   NaN              NaN                   NaN  ...
# 37               152,820           ±6,446                 12.7%  ...
# 38               383,127          ±13,345                 31.7%  ...
# 39               501,133          ±11,660                 41.5%  ...
# 40               169,731           ±7,834                 14.1%  ...
# 41                   NaN              NaN                   NaN  ...
# 42               903,687          ±14,230               903,687  ...
# 43               488,780          ±10,446                 54.1%  ...
# 44               410,779           ±9,616                 45.5%  ...
# 45                78,001           ±5,645                  8.6%  ...
# 46               414,907           ±9,822                 45.9%  ...
# 47               323,219          ±10,950                 35.8%  ...
# 48                91,688           ±6,535                 10.1%  ...
#
#             Unnamed: 123     Unnamed: 124             Unnamed: 125  \
# 0   Percent Distribution              NaN  Median income (dollars)
# 1               Estimate  Margin of Error                 Estimate
# 2                    NaN              NaN                      NaN
# 3                 29,168             ±873                   67,631
# 4                    NaN              NaN                      NaN
# 5                  90.9%             ±1.7                   63,892
# 6                      N                N                  126,023
# 7                      N                N                        -
# 8                      N                N                  165,178
# 9                      N                N                        -
# 10                     N                N                   68,029
# 11                     N                N                   75,101
# 12                     N                N                   76,109
# 13                 90.2%             ±1.6                   63,448
# 14                   NaN              NaN                      NaN
# 15                  2.7%             ±1.7                   20,234
# 16                 30.9%             ±2.1                   77,474
# 17                 35.2%             ±2.5                   70,895
# 18                 31.2%             ±1.9                   50,652
# 19                   NaN              NaN                      NaN
# 20                17,766           ±1,397                   89,903
# 21                     N                N                   86,365
# 22                     N                N                   93,030
# 23                     N                N                  102,553
# 24                     N                N                  106,034
# 25                     N                N                   48,290
# 26                     N                N                   40,355
# 27                     N                N                   56,758
# 28                     N                N                   42,459
# 29                   NaN              NaN                      NaN
# 30                 54.9%             ±5.2                   79,152
# 31                 15.8%             ±4.2                   94,817
# 32                 19.4%             ±4.7                  110,075
# 33                  5.2%             ±2.6                   61,306
# 34                  2.8%             ±2.0                   69,857
# 35                  1.8%             ±1.8                  133,450
# 36                   NaN              NaN                      NaN
# 37                 15.7%             ±3.3                   63,708
# 38                 31.7%             ±5.6                   60,778
# 39                 45.5%             ±5.1                  111,374
# 40                  7.2%             ±3.0                  130,927
# 41                   NaN              NaN                      NaN
# 42                11,402           ±1,339                   42,483
# 43                 55.0%             ±6.5                   29,769
# 44                 45.0%             ±5.6                   29,171
# 45                 10.0%             ±5.5                   52,725
# 46                 45.0%             ±6.5                   44,799
# 47                 37.5%             ±7.2                   45,629
# 48                  7.6%             ±4.4                   44,092
#
#        Unnamed: 126 Winnebago County, Illinois     Unnamed: 128  \
# 0               NaN                     Number              NaN
# 1   Margin of Error                   Estimate  Margin of Error
# 2               NaN                        NaN              NaN
# 3            ±8,022                    115,061           ±2,132
# 4               NaN                        NaN              NaN
# 5            ±7,981                     85,583           ±1,908
# 6          ±109,451                     11,933           ±1,226
# 7                **                          N                N
# 8          ±158,398                          N                N
# 9                **                          N                N
# 10          ±28,324                      4,238           ±1,007
# 11           ±9,148                     10,630           ±1,628
# 12          ±10,173                     11,533           ±1,083
# 13           ±7,980                     83,668           ±1,867
# 14              NaN                        NaN              NaN
# 15          ±29,516                      4,993           ±1,147
# 16           ±8,511                     34,864           ±1,543
# 17          ±17,543                     41,254           ±1,645
# 18           ±6,006                     33,950           ±1,189
# 19              NaN                        NaN              NaN
# 20          ±10,585                     71,558           ±3,009
# 21          ±11,760                     28,869           ±2,504
# 22          ±16,695                     42,689           ±2,502
# 23           ±8,334                     49,591           ±3,015
# 24          ±11,114                     17,555           ±2,019
# 25          ±17,301                     16,345           ±2,074
# 26          ±10,465                      8,778           ±1,795
# 27          ±26,524                      5,622           ±1,368
# 28          ±17,645                      2,536           ±1,034
# 29              NaN                        NaN              NaN
# 30          ±11,027                     35,327           ±2,426
# 31          ±20,210                     14,454           ±1,984
# 32          ±17,852                     12,039           ±1,755
# 33          ±43,474                      6,405           ±1,364
# 34         ±104,649                      2,552           ±1,039
# 35          ±51,156                        781             ±421
# 36              NaN                        NaN              NaN
# 37          ±28,766                     12,882           ±1,392
# 38          ±12,427                     21,929           ±2,313
# 39          ±17,177                     29,260           ±2,485
# 40          ±41,453                      7,487           ±1,216
# 41              NaN                        NaN              NaN
# 42           ±5,117                     43,503           ±2,776
# 43          ±13,678                     24,118           ±2,104
# 44          ±10,928                     20,312           ±1,841
# 45          ±52,938                      3,806           ±1,091
# 46           ±6,932                     19,385           ±1,882
# 47           ±7,733                     15,451           ±1,625
# 48          ±22,152                      3,934           ±1,144
#
#             Unnamed: 129     Unnamed: 130             Unnamed: 131  \
# 0   Percent Distribution              NaN  Median income (dollars)
# 1               Estimate  Margin of Error                 Estimate
# 2                    NaN              NaN                      NaN
# 3                115,061           ±2,132                   62,011
# 4                    NaN              NaN                      NaN
# 5                  74.4%             ±1.1                   66,517
# 6                  10.4%             ±1.1                   35,681
# 7                      N                N                        N
# 8                      N                N                   66,566
# 9                      N                N                        -
# 10                  3.7%             ±0.9                   77,599
# 11                  9.2%             ±1.4                   58,406
# 12                 10.0%             ±0.9                   65,568
# 13                 72.7%             ±1.2                   66,567
# 14                   NaN              NaN                      NaN
# 15                  4.3%             ±1.0                   37,785
# 16                 30.3%             ±1.2                   71,235
# 17                 35.9%             ±1.2                   78,708
# 18                 29.5%             ±1.1                   49,332
# 19                   NaN              NaN                      NaN
# 20                71,558           ±3,009                   80,840
# 21                 40.3%             ±2.8                   74,245
# 22                 59.7%             ±2.8                   84,451
# 23                 69.3%             ±3.2                  100,863
# 24                 24.5%             ±2.5                  107,421
# 25                 22.8%             ±2.8                   42,086
# 26                 12.3%             ±2.4                   27,930
# 27                  7.9%             ±1.8                   59,690
# 28                  3.5%             ±1.4                   61,015
# 29                   NaN              NaN                      NaN
# 30                 49.4%             ±3.0                   74,425
# 31                 20.2%             ±2.7                   80,778
# 32                 16.8%             ±2.2                  105,706
# 33                  9.0%             ±1.9                   95,291
# 34                  3.6%             ±1.4                   98,662
# 35                  1.1%             ±0.6                   60,032
# 36                   NaN              NaN                      NaN
# 37                 18.0%             ±1.8                   47,432
# 38                 30.6%             ±2.9                   53,300
# 39                 40.9%             ±3.0                  105,428
# 40                 10.5%             ±1.7                  131,319
# 41                   NaN              NaN                      NaN
# 42                43,503           ±2,776                   36,763
# 43                 55.4%             ±3.3                   32,836
# 44                 46.7%             ±3.2                   31,090
# 45                  8.7%             ±2.4                   53,599
# 46                 44.6%             ±3.3                   41,174
# 47                 35.5%             ±3.0                   38,617
# 48                  9.0%             ±2.5                   66,500
#
#        Unnamed: 132
# 0               NaN
# 1   Margin of Error
# 2               NaN
# 3            ±3,198
# 4               NaN
# 5            ±3,945
# 6            ±8,945
# 7                 N
# 8           ±40,462
# 9                **
# 10          ±12,052
# 11           ±8,320
# 12          ±14,280
# 13           ±4,017
# 14              NaN
# 15           ±4,464
# 16           ±6,098
# 17           ±9,282
# 18           ±4,157
# 19              NaN
# 20           ±5,280
# 21           ±8,648
# 22           ±5,839
# 23           ±4,919
# 24           ±6,182
# 25          ±10,620
# 26          ±10,205
# 27           ±5,065
# 28          ±16,765
# 29              NaN
# 30           ±5,431
# 31           ±8,687
# 32          ±15,772
# 33          ±21,864
# 34          ±10,538
# 35          ±28,395
# 36              NaN
# 37           ±7,347
# 38           ±2,853
# 39           ±5,044
# 40          ±11,861
# 41              NaN
# 42           ±1,750
# 43           ±2,743
# 44           ±3,421
# 45          ±23,916
# 46           ±3,707
# 47           ±4,085
# 48          ±18,824
#
# [49 rows x 133 columns]
